# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
p = figure(plot_width=400, plot_height=400)

p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=10, line_color="navy", fill_color="orange", fill_alpha=0.8)

show(p)
# Out:
#   <div class="bk-root" id="9ce42fb0-bf8a-41a8-b52b-28a4704c57ce" data-root-id="1211"></div>

# %%
from bokeh.io import output_file, show

# %%
output_file("plot.html")

# %%
p = figure(plot_width=400, plot_height=400)

p.circle([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], size=15, line_color="navy", fill_color="orange", fill_alpha=0.5)

show(p)
# Out:
#   <div class="bk-root" id="d35417b5-9da7-4218-aba7-2873aca9203d" data-root-id="1329"></div>
